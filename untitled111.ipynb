# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datasist as ds

# %matplotlib inline
pd.set_option('max_colwidth', 100)

# %%
train = pd.read_csv("Train.csv")
test = pd.read_csv("Test.csv")
riders = pd.read_csv("Riders.csv")
sample = pd.read_csv("SampleSubmission.csv")
datadef = pd.read_csv("VariableDefinitions.csv")

# %%
datadef
# Out:
#                                      Order No  \
# 0                                     User Id
# 1                                Vehicle Type
# 2                               Platform Type
# 3                        Personal or Business
# 4                    Placement - Day of Month
# 5                Placement - Weekday (Mo = 1)
# 6                            Placement - Time
# 7                 Confirmation - Day of Month
# 8             Confirmation - Weekday (Mo = 1)
# 9                         Confirmation - Time
# 10           Arrival at Pickup - Day of Month
# 11       Arrival at Pickup - Weekday (Mo = 1)
# 12                   Arrival at Pickup - Time
# 13                      Pickup - Day of Month
# 14                  Pickup - Weekday (Mo = 1)
# 15                              Pickup - Time
# 16      Arrival at Destination - Day of Month
# 17  Arrival at Destination - Weekday (Mo = 1)
# 18              Arrival at Destination - Time
# ...

# %%
#Merge riders dataset to train datasets
train_merged = train.merge(riders, how='left', on='Rider Id')

# %%
ds.structdata.describe(train_merged)
# Out:
# First five data points
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# ...

# %% [markdown]
# ### Feature Engineering

# %%
ds.feature_engineering.drop_redundant(train_merged)

# %%
ds.feature_engineering.drop_missing(train_merged, percent=80)

# %%
train_merged.shape
# Out:
# (21201, 31)

# %%
#Get columns
cat_cols = ds.structdata.get_cat_feats(train_merged)
num_cols = ds.structdata.get_num_feats(train_merged)
time_cols = ['Arrival at Destination - Time', 'Pickup - Time', 'Arrival at Pickup - Time', 'Confirmation - Time', 'Placement - Time']

# %%
#get hours, minute and seconds from time columns
train_merged = ds.timeseries.extract_time(data=train_merged, time_cols=time_cols)

# %%
ds.structdata.display_missing(train_merged)
# Out:
#                                      features  missing_counts  missing_percent
# 0                                    Order No               0             0.00
# 1                                     User Id               0             0.00
# 2                               Platform Type               0             0.00
# 3                        Personal or Business               0             0.00
# 4                    Placement - Day of Month               0             0.00
# 5                Placement - Weekday (Mo = 1)               0             0.00
# 6                 Confirmation - Day of Month               0             0.00
# 7             Confirmation - Weekday (Mo = 1)               0             0.00
# 8            Arrival at Pickup - Day of Month               0             0.00
# 9        Arrival at Pickup - Weekday (Mo = 1)               0             0.00
# 10                      Pickup - Day of Month               0             0.00
# ...
